# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

torch.manual_seed(0)

# ----------------------------
# Dummy denoising model
# ----------------------------
class DummyModel(nn.Module):
    """
    This model pretends to predict x0.
    It simply outputs random logits so we can
    test the D3PM mechanics.
    """
    def __init__(self, vocab_size):
        super().__init__()
        self.vocab_size = vocab_size

    def forward(self, x_t, t, domain, seq_boundaries=None, max_seqlen=None):
        B, L = x_t.shape
        logits = torch.randn(B, L, self.vocab_size)
        return {"logits": logits}


# ----------------------------
# D3PM (slightly instrumented)
# ----------------------------
class D3PM:
    def __init__(self, vocab_size, T=5, mask_id=2):
        self.K = vocab_size
        self.T = T
        self.mask_id = mask_id

        betas = torch.linspace(1e-4, 0.02, T)
        alphas = 1.0 - betas
        alphas_cumprod = torch.cumprod(alphas, dim=0)

        self.betas = betas
        self.alphas = alphas
        self.alphas_cumprod = alphas_cumprod

        print("Initialized D3PM")
        print("betas:", betas)
        print("alphas:", alphas)
        print("alphas_cumprod:", alphas_cumprod)
        print("-" * 50)

    def _get_Qt_bar(self, t, device):
        alpha_bar = self.alphas_cumprod.to(device)[t - 1]
        Qt_bar = torch.zeros(len(t), self.K, self.K, device=device)

        for i in range(len(t)):
            ab = alpha_bar[i]
            Qt_bar[i] = torch.eye(self.K, device=device) * ab
            Qt_bar[i, :, self.mask_id] += (1 - ab)

        print(f"Qt_bar (t={t.tolist()}):\n", Qt_bar)
        return Qt_bar

    def q_sample(self, x0, t):
        B, L = x0.shape
        device = x0.device

        print("\n--- FORWARD DIFFUSION q_sample ---")
        print("x0:", x0)
        print("t:", t)

        Qt_bar = self._get_Qt_bar(t, device)
        x0_onehot = F.one_hot(x0, self.K).float()

        qt = torch.einsum('blk,bkj->blj', x0_onehot, Qt_bar)
        print("q(x_t | x0):", qt)

        x_t = torch.multinomial(qt.view(-1, self.K), 1).view(B, L)
        print("Sampled x_t:", x_t)
        return x_t

    def _get_Qt(self, t, device):
        alpha = self.alphas.to(device)[t - 1]
        Qt = torch.eye(self.K, device=device) * alpha
        Qt[:, self.mask_id] += (1 - alpha)
        return Qt.unsqueeze(0)

    def p_sample(self, model, x_t, t, domain, seq_boundaries, max_seqlen):
        device = x_t.device
        B, L = x_t.shape

        print(f"\n--- REVERSE STEP p_sample (t={t}) ---")
        print("x_t:", x_t)

        t_batch = torch.full((B,), t, device=device, dtype=torch.long)

        with torch.no_grad():
            output = model(x_t, t_batch, domain)
            logits = output["logits"]
            p_x0 = F.softmax(logits, dim=-1)

        print("Predicted p(x0 | x_t):", p_x0)

        if t <= 1:
            x_tm1 = torch.multinomial(p_x0.view(-1, self.K), 1).view(B, L)
            print("Final x0 sample:", x_tm1)
            return x_tm1

        Qt = self._get_Qt(t, device)[0]
        Qt_1_bar = self._get_Qt_bar(torch.tensor([t - 1], device=device), device)[0]

        q_xt_given_xt_1 = Qt[:, x_t].permute(1, 2, 0)
        q_xt_1_given_x0 = torch.einsum('blk,kj->blj', p_x0, Qt_1_bar)

        posterior = q_xt_given_xt_1 * q_xt_1_given_x0
        posterior = posterior / (posterior.sum(dim=-1, keepdim=True) + 1e-8)

        print("Posterior p(x_{t-1} | x_t):", posterior)

        x_tm1 = torch.multinomial(posterior.view(-1, self.K), 1).view(B, L)
        print("Sampled x_{t-1}:", x_tm1)

        return x_tm1


# ----------------------------
# MAIN DEMO
# ----------------------------
def main():
    vocab_size = 5     # tokens: {0,1,2,3,4}
    mask_id = 2
    T = 95

    d3pm = D3PM(vocab_size=vocab_size, T=T, mask_id=mask_id)
    model = DummyModel(vocab_size)

    # Fake data
    B, L = 1, 4
    x0 = torch.tensor([[0, 1, 3, 4]])
    domain = torch.zeros_like(x0)

    # Sample random timestep
    t = torch.tensor([T])

    # Forward diffusion
    x_t = d3pm.q_sample(x0, t)

    # Reverse diffusion loop
    for step in reversed(range(1, T + 1)):
        x_t = d3pm.p_sample(
            model=model,
            x_t=x_t,
            t=step,
            domain=domain,
            seq_boundaries=None,
            max_seqlen=L
        )

    print("\n=== FINAL RESULT ===")
    print("Original x0:", x0)
    print("Reconstructed x0_hat:", x_t)


if __name__ == "__main__":
    main()
# Out:
# Initialized D3PM
# betas: tensor([1.0000e-04, 3.1170e-04, 5.2340e-04, 7.3511e-04, 9.4681e-04, 1.1585e-03,
#         1.3702e-03, 1.5819e-03, 1.7936e-03, 2.0053e-03, 2.2170e-03, 2.4287e-03,
#         2.6404e-03, 2.8521e-03, 3.0638e-03, 3.2755e-03, 3.4872e-03, 3.6989e-03,
#         3.9106e-03, 4.1223e-03, 4.3340e-03, 4.5457e-03, 4.7574e-03, 4.9691e-03,
#         5.1809e-03, 5.3926e-03, 5.6043e-03, 5.8160e-03, 6.0277e-03, 6.2394e-03,
#         6.4511e-03, 6.6628e-03, 6.8745e-03, 7.0862e-03, 7.2979e-03, 7.5096e-03,
#         7.7213e-03, 7.9330e-03, 8.1447e-03, 8.3564e-03, 8.5681e-03, 8.7798e-03,
#         8.9915e-03, 9.2032e-03, 9.4149e-03, 9.6266e-03, 9.8383e-03, 1.0050e-02,
#         1.0262e-02, 1.0473e-02, 1.0685e-02, 1.0897e-02, 1.1109e-02, 1.1320e-02,
#         1.1532e-02, 1.1744e-02, 1.1955e-02, 1.2167e-02, 1.2379e-02, 1.2590e-02,
#         1.2802e-02, 1.3014e-02, 1.3226e-02, 1.3437e-02, 1.3649e-02, 1.3861e-02,
#         1.4072e-02, 1.4284e-02, 1.4496e-02, 1.4707e-02, 1.4919e-02, 1.5131e-02,
#         1.5343e-02, 1.5554e-02, 1.5766e-02, 1.5978e-02, 1.6189e-02, 1.6401e-02,
#         1.6613e-02, 1.6824e-02, 1.7036e-02, 1.7248e-02, 1.7460e-02, 1.7671e-02,
#         1.7883e-02, 1.8095e-02, 1.8306e-02, 1.8518e-02, 1.8730e-02, 1.8941e-02,
#         1.9153e-02, 1.9365e-02, 1.9577e-02, 1.9788e-02, 2.0000e-02])
# alphas: tensor([0.9999, 0.9997, 0.9995, 0.9993, 0.9991, 0.9988, 0.9986, 0.9984, 0.9982,
#         0.9980, 0.9978, 0.9976, 0.9974, 0.9971, 0.9969, 0.9967, 0.9965, 0.9963,
#         0.9961, 0.9959, 0.9957, 0.9955, 0.9952, 0.9950, 0.9948, 0.9946, 0.9944,
#         0.9942, 0.9940, 0.9938, 0.9935, 0.9933, 0.9931, 0.9929, 0.9927, 0.9925,
#         0.9923, 0.9921, 0.9919, 0.9916, 0.9914, 0.9912, 0.9910, 0.9908, 0.9906,
#         0.9904, 0.9902, 0.9900, 0.9897, 0.9895, 0.9893, 0.9891, 0.9889, 0.9887,
#         0.9885, 0.9883, 0.9880, 0.9878, 0.9876, 0.9874, 0.9872, 0.9870, 0.9868,
#         0.9866, 0.9864, 0.9861, 0.9859, 0.9857, 0.9855, 0.9853, 0.9851, 0.9849,
#         0.9847, 0.9844, 0.9842, 0.9840, 0.9838, 0.9836, 0.9834, 0.9832, 0.9830,
#         0.9828, 0.9825, 0.9823, 0.9821, 0.9819, 0.9817, 0.9815, 0.9813, 0.9811,
#         0.9808, 0.9806, 0.9804, 0.9802, 0.9800])
# alphas_cumprod: tensor([0.9999, 0.9996, 0.9991, 0.9983, 0.9974, 0.9962, 0.9949, 0.9933, 0.9915,
#         0.9895, 0.9873, 0.9849, 0.9823, 0.9795, 0.9765, 0.9733, 0.9699, 0.9663,
#         0.9626, 0.9586, 0.9544, 0.9501, 0.9456, 0.9409, 0.9360, 0.9310, 0.9257,
#         0.9204, 0.9148, 0.9091, 0.9032, 0.8972, 0.8911, 0.8847, 0.8783, 0.8717,
#         0.8650, 0.8581, 0.8511, 0.8440, 0.8368, 0.8294, 0.8220, 0.8144, 0.8067,
#         0.7990, 0.7911, 0.7832, 0.7751, 0.7670, 0.7588, 0.7505, 0.7422, 0.7338,
#         0.7253, 0.7168, 0.7082, 0.6996, 0.6910, 0.6823, 0.6735, 0.6648, 0.6560,
#         0.6472, 0.6383, 0.6295, 0.6206, 0.6118, 0.6029, 0.5940, 0.5852, 0.5763,
#         0.5675, 0.5586, 0.5498, 0.5410, 0.5323, 0.5236, 0.5149, 0.5062, 0.4976,
#         0.4890, 0.4805, 0.4720, 0.4635, 0.4551, 0.4468, 0.4385, 0.4303, 0.4222,
#         0.4141, 0.4061, 0.3981, 0.3902, 0.3824])
# --------------------------------------------------
#
# --- FORWARD DIFFUSION q_sample ---
# x0: tensor([[0, 1, 3, 4]])
# t: tensor([95])
# Qt_bar (t=[95]):
#  tensor([[[0.3824, 0.0000, 0.6176, 0.0000, 0.0000],
#          [0.0000, 0.3824, 0.6176, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.6176, 0.3824, 0.0000],
#          [0.0000, 0.0000, 0.6176, 0.0000, 0.3824]]])
# q(x_t | x0): tensor([[[0.3824, 0.0000, 0.6176, 0.0000, 0.0000],
#          [0.0000, 0.3824, 0.6176, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.6176, 0.3824, 0.0000],
#          [0.0000, 0.0000, 0.6176, 0.0000, 0.3824]]])
# Sampled x_t: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=95) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.1311, 0.0774, 0.2856, 0.2110, 0.2948],
#          [0.4691, 0.1667, 0.0556, 0.0568, 0.2518],
#          [0.3273, 0.3915, 0.0241, 0.0888, 0.1683],
#          [0.6531, 0.0340, 0.1002, 0.1074, 0.1053]]])
# Qt_bar (t=[94]):
#  tensor([[[0.3902, 0.0000, 0.6098, 0.0000, 0.0000],
#          [0.0000, 0.3902, 0.6098, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.6098, 0.3902, 0.0000],
#          [0.0000, 0.0000, 0.6098, 0.0000, 0.3902]]])
# Posterior p(x_{t-1} | x_t): tensor([[[1.4081e-03, 8.3156e-04, 9.9233e-01, 2.2653e-03, 3.1658e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [4.0754e-03, 4.8746e-03, 9.8785e-01, 1.1055e-03, 2.0953e-03],
#          [7.7718e-03, 4.0491e-04, 9.8929e-01, 1.2781e-03, 1.2530e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=94) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.3078, 0.1667, 0.0468, 0.1111, 0.3677],
#          [0.1135, 0.2576, 0.0196, 0.1211, 0.4883],
#          [0.6563, 0.1233, 0.0671, 0.1385, 0.0147],
#          [0.0457, 0.6526, 0.1515, 0.0758, 0.0745]]])
# Qt_bar (t=[93]):
#  tensor([[[0.3981, 0.0000, 0.6019, 0.0000, 0.0000],
#          [0.0000, 0.3981, 0.6019, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.6019, 0.3981, 0.0000],
#          [0.0000, 0.0000, 0.6019, 0.0000, 0.3981]]])
# Posterior p(x_{t-1} | x_t): tensor([[[3.8607e-03, 2.0907e-03, 9.8804e-01, 1.3939e-03, 4.6121e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [8.1304e-03, 1.5276e-03, 9.8844e-01, 1.7157e-03, 1.8192e-04],
#          [5.3834e-04, 7.6862e-03, 9.9001e-01, 8.9224e-04, 8.7694e-04]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=93) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.1030, 0.3073, 0.2708, 0.2675, 0.0515],
#          [0.4391, 0.0998, 0.0454, 0.2538, 0.1619],
#          [0.5284, 0.1048, 0.1848, 0.1340, 0.0479],
#          [0.0941, 0.1283, 0.0505, 0.5778, 0.1492]]])
# Qt_bar (t=[92]):
#  tensor([[[0.4061, 0.0000, 0.5939, 0.0000, 0.0000],
#          [0.0000, 0.4061, 0.5939, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.5939, 0.4061, 0.0000],
#          [0.0000, 0.0000, 0.5939, 0.0000, 0.4061]]])
# Posterior p(x_{t-1} | x_t): tensor([[[1.1537e-03, 3.4422e-03, 9.9183e-01, 2.9959e-03, 5.7637e-04],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [6.2189e-03, 1.2335e-03, 9.9041e-01, 1.5775e-03, 5.6403e-04],
#          [1.2031e-03, 1.6400e-03, 9.8787e-01, 7.3847e-03, 1.9070e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=92) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.6177, 0.1532, 0.0387, 0.0495, 0.1409],
#          [0.4582, 0.1726, 0.0999, 0.1915, 0.0779],
#          [0.2159, 0.1246, 0.0901, 0.4615, 0.1079],
#          [0.3082, 0.3646, 0.0454, 0.2269, 0.0548]]])
# Qt_bar (t=[91]):
#  tensor([[[0.4141, 0.0000, 0.5859, 0.0000, 0.0000],
#          [0.0000, 0.4141, 0.5859, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.5859, 0.4141, 0.0000],
#          [0.0000, 0.0000, 0.5859, 0.0000, 0.4141]]])
# Posterior p(x_{t-1} | x_t): tensor([[[8.1249e-03, 2.0154e-03, 9.8736e-01, 6.5054e-04, 1.8525e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [2.7459e-03, 1.5851e-03, 9.8843e-01, 5.8686e-03, 1.3723e-03],
#          [4.0361e-03, 4.7748e-03, 9.8750e-01, 2.9710e-03, 7.1773e-04]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=91) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.1062, 0.0811, 0.0462, 0.1250, 0.6415],
#          [0.0624, 0.5841, 0.0740, 0.1136, 0.1659],
#          [0.0608, 0.1778, 0.1354, 0.5743, 0.0517],
#          [0.3860, 0.2045, 0.1591, 0.1721, 0.0782]]])
# Qt_bar (t=[90]):
#  tensor([[[0.4222, 0.0000, 0.5778, 0.0000, 0.0000],
#          [0.0000, 0.4222, 0.5778, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.5778, 0.4222, 0.0000],
#          [0.0000, 0.0000, 0.5778, 0.0000, 0.4222]]])
# Posterior p(x_{t-1} | x_t): tensor([[[1.4191e-03, 1.0833e-03, 9.8725e-01, 1.6711e-03, 8.5735e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [7.6563e-04, 2.2390e-03, 9.8911e-01, 7.2336e-03, 6.5178e-04],
#          [4.7883e-03, 2.5368e-03, 9.8957e-01, 2.1353e-03, 9.7045e-04]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=90) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.1520, 0.1523, 0.4249, 0.1056, 0.1652],
#          [0.1652, 0.3346, 0.1768, 0.1775, 0.1458],
#          [0.1971, 0.4588, 0.1276, 0.1381, 0.0784],
#          [0.0394, 0.2593, 0.0282, 0.5459, 0.1273]]])
# Qt_bar (t=[89]):
#  tensor([[[0.4303, 0.0000, 0.5697, 0.0000, 0.0000],
#          [0.0000, 0.4303, 0.5697, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.5697, 0.4303, 0.0000],
#          [0.0000, 0.0000, 0.5697, 0.0000, 0.4303]]])
# Posterior p(x_{t-1} | x_t): tensor([[[1.6358e-03, 1.6397e-03, 9.9381e-01, 1.1365e-03, 1.7784e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [2.5438e-03, 5.9195e-03, 9.8874e-01, 1.7824e-03, 1.0115e-03],
#          [5.4466e-04, 3.5836e-03, 9.8657e-01, 7.5443e-03, 1.7589e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=89) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.3178, 0.2411, 0.0598, 0.1089, 0.2723],
#          [0.1252, 0.6716, 0.0588, 0.0284, 0.1159],
#          [0.3602, 0.1384, 0.1684, 0.2815, 0.0515],
#          [0.2875, 0.1284, 0.3364, 0.1258, 0.1219]]])
# Qt_bar (t=[88]):
#  tensor([[[0.4385, 0.0000, 0.5615, 0.0000, 0.0000],
#          [0.0000, 0.4385, 0.5615, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.5615, 0.4385, 0.0000],
#          [0.0000, 0.0000, 0.5615, 0.0000, 0.4385]]])
# Posterior p(x_{t-1} | x_t): tensor([[[4.3842e-03, 3.3265e-03, 9.8703e-01, 1.5029e-03, 3.7570e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [4.6074e-03, 1.7700e-03, 9.8936e-01, 3.6005e-03, 6.5925e-04],
#          [3.3051e-03, 1.4762e-03, 9.9237e-01, 1.4462e-03, 1.4009e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=88) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.0839, 0.2519, 0.4354, 0.0314, 0.1975],
#          [0.0406, 0.2634, 0.5199, 0.0998, 0.0763],
#          [0.0675, 0.0413, 0.0639, 0.6192, 0.2080],
#          [0.0290, 0.0543, 0.4802, 0.0026, 0.4339]]])
# Qt_bar (t=[87]):
#  tensor([[[0.4468, 0.0000, 0.5532, 0.0000, 0.0000],
#          [0.0000, 0.4468, 0.5532, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.5532, 0.4468, 0.0000],
#          [0.0000, 0.0000, 0.5532, 0.0000, 0.4468]]])
# Posterior p(x_{t-1} | x_t): tensor([[[9.2227e-04, 2.7704e-03, 9.9379e-01, 3.4497e-04, 2.1717e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [9.4740e-04, 5.7993e-04, 9.8686e-01, 8.6909e-03, 2.9195e-03],
#          [3.1050e-04, 5.8203e-04, 9.9443e-01, 2.7456e-05, 4.6502e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=87) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.1266, 0.4897, 0.1681, 0.1322, 0.0834],
#          [0.0184, 0.1726, 0.0778, 0.4059, 0.3253],
#          [0.0577, 0.0320, 0.3747, 0.3232, 0.2124],
#          [0.2312, 0.0708, 0.3750, 0.1749, 0.1481]]])
# Qt_bar (t=[86]):
#  tensor([[[0.4551, 0.0000, 0.5449, 0.0000, 0.0000],
#          [0.0000, 0.4551, 0.5449, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.5449, 0.4551, 0.0000],
#          [0.0000, 0.0000, 0.5449, 0.0000, 0.4551]]])
# Posterior p(x_{t-1} | x_t): tensor([[[1.6783e-03, 6.4937e-03, 9.8897e-01, 1.7532e-03, 1.1064e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [6.6704e-04, 3.6954e-04, 9.9277e-01, 3.7374e-03, 2.4560e-03],
#          [2.6730e-03, 8.1836e-04, 9.9278e-01, 2.0215e-03, 1.7120e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=86) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.0577, 0.0258, 0.4577, 0.1469, 0.3120],
#          [0.6868, 0.0148, 0.0518, 0.0720, 0.1745],
#          [0.2173, 0.4810, 0.0779, 0.0819, 0.1418],
#          [0.0752, 0.3521, 0.0644, 0.1888, 0.3195]]])
# Qt_bar (t=[85]):
#  tensor([[[0.4635, 0.0000, 0.5365, 0.0000, 0.0000],
#          [0.0000, 0.4635, 0.5365, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.5365, 0.4635, 0.0000],
#          [0.0000, 0.0000, 0.5365, 0.0000, 0.4635]]])
# Posterior p(x_{t-1} | x_t): tensor([[[6.4212e-04, 2.8693e-04, 9.9396e-01, 1.6358e-03, 3.4738e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [3.1412e-03, 6.9521e-03, 9.8667e-01, 1.1840e-03, 2.0493e-03],
#          [1.0986e-03, 5.1434e-03, 9.8633e-01, 2.7583e-03, 4.6673e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=85) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.1077, 0.1946, 0.3395, 0.3209, 0.0372],
#          [0.1020, 0.5147, 0.1198, 0.0935, 0.1701],
#          [0.5826, 0.1624, 0.0234, 0.1879, 0.0436],
#          [0.2402, 0.0991, 0.3566, 0.2438, 0.0602]]])
# Qt_bar (t=[84]):
#  tensor([[[0.4720, 0.0000, 0.5280, 0.0000, 0.0000],
#          [0.0000, 0.4720, 0.5280, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.5280, 0.4720, 0.0000],
#          [0.0000, 0.0000, 0.5280, 0.0000, 0.4720]]])
# Posterior p(x_{t-1} | x_t): tensor([[[1.3104e-03, 2.3674e-03, 9.9197e-01, 3.9040e-03, 4.5304e-04],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [8.9848e-03, 2.5048e-03, 9.8494e-01, 2.8975e-03, 6.7298e-04],
#          [2.8889e-03, 1.1922e-03, 9.9226e-01, 2.9319e-03, 7.2459e-04]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=84) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.2155, 0.1775, 0.1420, 0.3101, 0.1548],
#          [0.0634, 0.5513, 0.1006, 0.0218, 0.2629],
#          [0.1694, 0.0659, 0.1179, 0.2418, 0.4050],
#          [0.1379, 0.0789, 0.7736, 0.0030, 0.0067]]])
# Qt_bar (t=[83]):
#  tensor([[[0.4805, 0.0000, 0.5195, 0.0000, 0.0000],
#          [0.0000, 0.4805, 0.5195, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.5195, 0.4805, 0.0000],
#          [0.0000, 0.0000, 0.5195, 0.0000, 0.4805]]])
# Posterior p(x_{t-1} | x_t): tensor([[[3.0753e-03, 2.5322e-03, 9.8776e-01, 4.4249e-03, 2.2087e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [2.4638e-03, 9.5791e-04, 9.8717e-01, 3.5169e-03, 5.8913e-03],
#          [1.3106e-03, 7.4962e-04, 9.9785e-01, 2.8745e-05, 6.3439e-05]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=83) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.1008, 0.0536, 0.4290, 0.4086, 0.0081],
#          [0.5674, 0.0513, 0.1046, 0.0193, 0.2574],
#          [0.0492, 0.0089, 0.8594, 0.0528, 0.0298],
#          [0.2317, 0.0326, 0.5599, 0.0705, 0.1054]]])
# Qt_bar (t=[82]):
#  tensor([[[0.4890, 0.0000, 0.5110, 0.0000, 0.0000],
#          [0.0000, 0.4890, 0.5110, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.5110, 0.4890, 0.0000],
#          [0.0000, 0.0000, 0.5110, 0.0000, 0.4890]]])
# Posterior p(x_{t-1} | x_t): tensor([[[1.1858e-03, 6.3042e-04, 9.9328e-01, 4.8072e-03, 9.4746e-05],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [4.5013e-04, 8.1697e-05, 9.9871e-01, 4.8333e-04, 2.7246e-04],
#          [2.5082e-03, 3.5246e-04, 9.9523e-01, 7.6328e-04, 1.1411e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=82) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.1729, 0.0218, 0.5593, 0.1409, 0.1051],
#          [0.0475, 0.2208, 0.0613, 0.1212, 0.5493],
#          [0.1632, 0.5334, 0.1614, 0.0318, 0.1102],
#          [0.1994, 0.6041, 0.0417, 0.0695, 0.0852]]])
# Qt_bar (t=[81]):
#  tensor([[[0.4976, 0.0000, 0.5024, 0.0000, 0.0000],
#          [0.0000, 0.4976, 0.5024, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.5024, 0.4976, 0.0000],
#          [0.0000, 0.0000, 0.5024, 0.0000, 0.4976]]])
# Posterior p(x_{t-1} | x_t): tensor([[[1.8909e-03, 2.3805e-04, 9.9518e-01, 1.5418e-03, 1.1498e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [2.3746e-03, 7.7591e-03, 9.8780e-01, 4.6282e-04, 1.6024e-03],
#          [3.2207e-03, 9.7553e-03, 9.8452e-01, 1.1231e-03, 1.3763e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=81) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.1581, 0.0865, 0.3091, 0.2873, 0.1590],
#          [0.5289, 0.1259, 0.1852, 0.0435, 0.1165],
#          [0.1391, 0.5532, 0.0838, 0.0714, 0.1525],
#          [0.2937, 0.2570, 0.1638, 0.1169, 0.1687]]])
# Qt_bar (t=[80]):
#  tensor([[[0.5062, 0.0000, 0.4938, 0.0000, 0.0000],
#          [0.0000, 0.5062, 0.4938, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.4938, 0.5062, 0.0000],
#          [0.0000, 0.0000, 0.4938, 0.0000, 0.5062]]])
# Posterior p(x_{t-1} | x_t): tensor([[[0.0021, 0.0011, 0.9909, 0.0038, 0.0021],
#          [0.0000, 1.0000, 0.0000, 0.0000, 0.0000],
#          [0.0022, 0.0088, 0.9855, 0.0011, 0.0024],
#          [0.0043, 0.0038, 0.9876, 0.0017, 0.0025]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=80) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.4218, 0.3532, 0.0191, 0.1703, 0.0357],
#          [0.4148, 0.0800, 0.1312, 0.1050, 0.2689],
#          [0.0454, 0.3980, 0.0377, 0.2058, 0.3131],
#          [0.2423, 0.1002, 0.2487, 0.2052, 0.2035]]])
# Qt_bar (t=[79]):
#  tensor([[[0.5149, 0.0000, 0.4851, 0.0000, 0.0000],
#          [0.0000, 0.5149, 0.4851, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.4851, 0.5149, 0.0000],
#          [0.0000, 0.0000, 0.4851, 0.0000, 0.5149]]])
# Posterior p(x_{t-1} | x_t): tensor([[[7.2576e-03, 6.0763e-03, 9.8312e-01, 2.9294e-03, 6.1385e-04],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [7.6608e-04, 6.7223e-03, 9.8375e-01, 3.4763e-03, 5.2884e-03],
#          [3.3868e-03, 1.4006e-03, 9.8950e-01, 2.8688e-03, 2.8448e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=79) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.0292, 0.0839, 0.0249, 0.7659, 0.0960],
#          [0.0679, 0.0384, 0.6023, 0.0803, 0.2111],
#          [0.1491, 0.1571, 0.0058, 0.3509, 0.3371],
#          [0.0794, 0.2997, 0.4922, 0.0673, 0.0614]]])
# Qt_bar (t=[78]):
#  tensor([[[0.5236, 0.0000, 0.4764, 0.0000, 0.0000],
#          [0.0000, 0.5236, 0.4764, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.4764, 0.5236, 0.0000],
#          [0.0000, 0.0000, 0.4764, 0.0000, 0.5236]]])
# Posterior p(x_{t-1} | x_t): tensor([[[5.1083e-04, 1.4650e-03, 9.8297e-01, 1.3377e-02, 1.6775e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [2.6561e-03, 2.7999e-03, 9.8229e-01, 6.2531e-03, 6.0059e-03],
#          [9.3533e-04, 3.5293e-03, 9.9402e-01, 7.9210e-04, 7.2277e-04]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=78) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.3293, 0.0489, 0.0701, 0.3355, 0.2162],
#          [0.7400, 0.0874, 0.0726, 0.0382, 0.0618],
#          [0.1771, 0.1185, 0.0188, 0.1340, 0.5517],
#          [0.0181, 0.1043, 0.0869, 0.0461, 0.7446]]])
# Qt_bar (t=[77]):
#  tensor([[[0.5323, 0.0000, 0.4677, 0.0000, 0.0000],
#          [0.0000, 0.5323, 0.4677, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.4677, 0.5323, 0.0000],
#          [0.0000, 0.0000, 0.4677, 0.0000, 0.5323]]])
# Posterior p(x_{t-1} | x_t): tensor([[[5.6026e-03, 8.3168e-04, 9.8418e-01, 5.7067e-03, 3.6777e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [3.1791e-03, 2.1271e-03, 9.8238e-01, 2.4054e-03, 9.9039e-03],
#          [3.0354e-04, 1.7447e-03, 9.8473e-01, 7.7084e-04, 1.2455e-02]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=77) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.2572, 0.3455, 0.2440, 0.0734, 0.0798],
#          [0.1772, 0.2028, 0.4386, 0.1158, 0.0656],
#          [0.1024, 0.3255, 0.2041, 0.1732, 0.1947],
#          [0.0762, 0.5527, 0.1269, 0.1381, 0.1060]]])
# Qt_bar (t=[76]):
#  tensor([[[0.5410, 0.0000, 0.4590, 0.0000, 0.0000],
#          [0.0000, 0.5410, 0.4590, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.4590, 0.5410, 0.0000],
#          [0.0000, 0.0000, 0.4590, 0.0000, 0.5410]]])
# Posterior p(x_{t-1} | x_t): tensor([[[0.0038, 0.0051, 0.9889, 0.0011, 0.0012],
#          [0.0000, 1.0000, 0.0000, 0.0000, 0.0000],
#          [0.0016, 0.0049, 0.9879, 0.0026, 0.0030],
#          [0.0012, 0.0090, 0.9857, 0.0023, 0.0017]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=76) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.1073, 0.5894, 0.1052, 0.1001, 0.0980],
#          [0.2884, 0.0645, 0.5863, 0.0467, 0.0141],
#          [0.0383, 0.1438, 0.3302, 0.1925, 0.2951],
#          [0.1790, 0.2107, 0.1083, 0.1588, 0.3432]]])
# Qt_bar (t=[75]):
#  tensor([[[0.5498, 0.0000, 0.4502, 0.0000, 0.0000],
#          [0.0000, 0.5498, 0.4502, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.4502, 0.5498, 0.0000],
#          [0.0000, 0.0000, 0.4502, 0.0000, 0.5498]]])
# Posterior p(x_{t-1} | x_t): tensor([[[1.8268e-03, 1.0037e-02, 9.8476e-01, 1.7054e-03, 1.6690e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [5.2774e-04, 1.9812e-03, 9.9077e-01, 2.6523e-03, 4.0663e-03],
#          [3.0387e-03, 3.5767e-03, 9.8486e-01, 2.6959e-03, 5.8250e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=75) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.1886, 0.1015, 0.3212, 0.1484, 0.2404],
#          [0.1151, 0.3438, 0.1904, 0.2245, 0.1262],
#          [0.3236, 0.0448, 0.0785, 0.4249, 0.1282],
#          [0.0295, 0.5518, 0.1634, 0.1287, 0.1266]]])
# Qt_bar (t=[74]):
#  tensor([[[0.5586, 0.0000, 0.4414, 0.0000, 0.0000],
#          [0.0000, 0.5586, 0.4414, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.4414, 0.5586, 0.0000],
#          [0.0000, 0.0000, 0.4414, 0.0000, 0.5586]]])
# Posterior p(x_{t-1} | x_t): tensor([[[2.6497e-03, 1.4267e-03, 9.9046e-01, 2.0853e-03, 3.3776e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [5.7770e-03, 7.9997e-04, 9.8355e-01, 7.5850e-03, 2.2887e-03],
#          [4.8179e-04, 8.9999e-03, 9.8635e-01, 2.0998e-03, 2.0646e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=74) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.6840, 0.0180, 0.1269, 0.0865, 0.0847],
#          [0.1149, 0.2182, 0.4465, 0.1492, 0.0712],
#          [0.0859, 0.0472, 0.3129, 0.0511, 0.5029],
#          [0.3033, 0.2738, 0.2569, 0.0940, 0.0720]]])
# Qt_bar (t=[73]):
#  tensor([[[0.5675, 0.0000, 0.4325, 0.0000, 0.0000],
#          [0.0000, 0.5675, 0.4325, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.4325, 0.5675, 0.0000],
#          [0.0000, 0.0000, 0.4325, 0.0000, 0.5675]]])
# Posterior p(x_{t-1} | x_t): tensor([[[1.1786e-02, 3.0935e-04, 9.8496e-01, 1.4896e-03, 1.4587e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [1.2311e-03, 6.7581e-04, 9.9016e-01, 7.3244e-04, 7.2044e-03],
#          [4.5767e-03, 4.1324e-03, 9.8879e-01, 1.4186e-03, 1.0865e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=73) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.2874, 0.1277, 0.0443, 0.0371, 0.5035],
#          [0.8451, 0.0188, 0.0349, 0.0416, 0.0596],
#          [0.0159, 0.1411, 0.6221, 0.0583, 0.1626],
#          [0.0980, 0.2446, 0.1548, 0.0588, 0.4438]]])
# Qt_bar (t=[72]):
#  tensor([[[0.5763, 0.0000, 0.4237, 0.0000, 0.0000],
#          [0.0000, 0.5763, 0.4237, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.4237, 0.5763, 0.0000],
#          [0.0000, 0.0000, 0.4237, 0.0000, 0.5763]]])
# Posterior p(x_{t-1} | x_t): tensor([[[5.5527e-03, 2.4666e-03, 9.8154e-01, 7.1618e-04, 9.7268e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [1.7908e-04, 1.5887e-03, 9.9575e-01, 6.5574e-04, 1.8307e-03],
#          [1.6648e-03, 4.1569e-03, 9.8564e-01, 9.9962e-04, 7.5406e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=72) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.2287, 0.2021, 0.1263, 0.0266, 0.4162],
#          [0.0349, 0.1497, 0.7207, 0.0648, 0.0300],
#          [0.1205, 0.2059, 0.2746, 0.1293, 0.2696],
#          [0.2369, 0.2844, 0.0472, 0.0487, 0.3828]]])
# Qt_bar (t=[71]):
#  tensor([[[0.5852, 0.0000, 0.4148, 0.0000, 0.0000],
#          [0.0000, 0.5852, 0.4148, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.4148, 0.5852, 0.0000],
#          [0.0000, 0.0000, 0.4148, 0.0000, 0.5852]]])
# Posterior p(x_{t-1} | x_t): tensor([[[4.0787e-03, 3.6040e-03, 9.8442e-01, 4.7515e-04, 7.4215e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [1.8342e-03, 3.1332e-03, 9.8896e-01, 1.9675e-03, 4.1027e-03],
#          [4.6520e-03, 5.5837e-03, 9.8129e-01, 9.5608e-04, 7.5162e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=71) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.0922, 0.0962, 0.0628, 0.2018, 0.5469],
#          [0.0876, 0.6155, 0.1057, 0.1126, 0.0787],
#          [0.1345, 0.2216, 0.1637, 0.2426, 0.2375],
#          [0.3038, 0.3325, 0.2943, 0.0547, 0.0147]]])
# Qt_bar (t=[70]):
#  tensor([[[0.5940, 0.0000, 0.4060, 0.0000, 0.0000],
#          [0.0000, 0.5940, 0.4060, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.4060, 0.5940, 0.0000],
#          [0.0000, 0.0000, 0.4060, 0.0000, 0.5940]]])
# Posterior p(x_{t-1} | x_t): tensor([[[1.8102e-03, 1.8888e-03, 9.8161e-01, 3.9598e-03, 1.0733e-02],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [2.3345e-03, 3.8464e-03, 9.8549e-01, 4.2111e-03, 4.1214e-03],
#          [4.5865e-03, 5.0195e-03, 9.8935e-01, 8.2512e-04, 2.2216e-04]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=70) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.1396, 0.1446, 0.0464, 0.0397, 0.6297],
#          [0.2287, 0.2993, 0.0300, 0.1327, 0.3094],
#          [0.0543, 0.0702, 0.4735, 0.2901, 0.1119],
#          [0.4121, 0.0484, 0.1953, 0.1136, 0.2306]]])
# Qt_bar (t=[69]):
#  tensor([[[0.6029, 0.0000, 0.3971, 0.0000, 0.0000],
#          [0.0000, 0.6029, 0.3971, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.3971, 0.6029, 0.0000],
#          [0.0000, 0.0000, 0.3971, 0.0000, 0.6029]]])
# Posterior p(x_{t-1} | x_t): tensor([[[2.8554e-03, 2.9584e-03, 9.8049e-01, 8.1251e-04, 1.2879e-02],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [7.0080e-04, 9.0558e-04, 9.9321e-01, 3.7428e-03, 1.4441e-03],
#          [7.0000e-03, 8.2179e-04, 9.8633e-01, 1.9301e-03, 3.9170e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 2, 2]])
#
# --- REVERSE STEP p_sample (t=69) ---
# x_t: tensor([[2, 1, 2, 2]])
# Predicted p(x0 | x_t): tensor([[[0.1077, 0.0396, 0.4001, 0.2196, 0.2329],
#          [0.1026, 0.4553, 0.1437, 0.2048, 0.0936],
#          [0.5975, 0.1291, 0.0543, 0.1717, 0.0474],
#          [0.2146, 0.1899, 0.1806, 0.4112, 0.0037]]])
# Qt_bar (t=[68]):
#  tensor([[[0.6118, 0.0000, 0.3882, 0.0000, 0.0000],
#          [0.0000, 0.6118, 0.3882, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.3882, 0.6118, 0.0000],
#          [0.0000, 0.0000, 0.3882, 0.0000, 0.6118]]])
# Posterior p(x_{t-1} | x_t): tensor([[[1.4957e-03, 5.5069e-04, 9.9167e-01, 3.0510e-03, 3.2358e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [1.2328e-02, 2.6644e-03, 9.8049e-01, 3.5414e-03, 9.7728e-04],
#          [3.7617e-03, 3.3290e-03, 9.8564e-01, 7.2064e-03, 6.4620e-05]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 2]])
#
# --- REVERSE STEP p_sample (t=68) ---
# x_t: tensor([[2, 1, 1, 2]])
# Predicted p(x0 | x_t): tensor([[[0.8605, 0.0489, 0.0280, 0.0388, 0.0238],
#          [0.0983, 0.4095, 0.0830, 0.1735, 0.2357],
#          [0.4657, 0.1392, 0.1143, 0.0092, 0.2717],
#          [0.3287, 0.3616, 0.1286, 0.0887, 0.0924]]])
# Qt_bar (t=[67]):
#  tensor([[[0.6206, 0.0000, 0.3794, 0.0000, 0.0000],
#          [0.0000, 0.6206, 0.3794, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.3794, 0.6206, 0.0000],
#          [0.0000, 0.0000, 0.3794, 0.0000, 0.6206]]])
# Posterior p(x_{t-1} | x_t): tensor([[[1.8819e-02, 1.0688e-03, 9.7874e-01, 8.4823e-04, 5.2091e-04],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [6.2410e-03, 6.8654e-03, 9.8346e-01, 1.6832e-03, 1.7533e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 2]])
#
# --- REVERSE STEP p_sample (t=67) ---
# x_t: tensor([[2, 1, 1, 2]])
# Predicted p(x0 | x_t): tensor([[[0.4325, 0.0642, 0.2696, 0.1593, 0.0744],
#          [0.2755, 0.0776, 0.2217, 0.1780, 0.2472],
#          [0.3227, 0.0737, 0.1727, 0.2629, 0.1680],
#          [0.5613, 0.0531, 0.2850, 0.0639, 0.0367]]])
# Qt_bar (t=[66]):
#  tensor([[[0.6295, 0.0000, 0.3705, 0.0000, 0.0000],
#          [0.0000, 0.6295, 0.3705, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.3705, 0.6295, 0.0000],
#          [0.0000, 0.0000, 0.3705, 0.0000, 0.6295]]])
# Posterior p(x_{t-1} | x_t): tensor([[[7.0091e-03, 1.0401e-03, 9.8816e-01, 2.5819e-03, 1.2052e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [8.9380e-03, 8.4513e-04, 9.8861e-01, 1.0175e-03, 5.8463e-04]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 2]])
#
# --- REVERSE STEP p_sample (t=66) ---
# x_t: tensor([[2, 1, 1, 2]])
# Predicted p(x0 | x_t): tensor([[[0.3139, 0.5258, 0.0650, 0.0459, 0.0494],
#          [0.1819, 0.0627, 0.3611, 0.1054, 0.2890],
#          [0.1669, 0.1227, 0.0959, 0.2832, 0.3313],
#          [0.0380, 0.4328, 0.4330, 0.0300, 0.0662]]])
# Qt_bar (t=[65]):
#  tensor([[[0.6383, 0.0000, 0.3617, 0.0000, 0.0000],
#          [0.0000, 0.6383, 0.3617, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.3617, 0.6383, 0.0000],
#          [0.0000, 0.0000, 0.3617, 0.0000, 0.6383]]])
# Posterior p(x_{t-1} | x_t): tensor([[[6.7509e-03, 1.1307e-02, 9.7989e-01, 9.8640e-04, 1.0621e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [5.2292e-04, 5.9550e-03, 9.9220e-01, 4.1240e-04, 9.1101e-04]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 2]])
#
# --- REVERSE STEP p_sample (t=65) ---
# x_t: tensor([[2, 1, 1, 2]])
# Predicted p(x0 | x_t): tensor([[[0.1000, 0.0518, 0.0462, 0.2740, 0.5280],
#          [0.0998, 0.0282, 0.0090, 0.0676, 0.7954],
#          [0.0604, 0.1195, 0.0811, 0.5448, 0.1943],
#          [0.0312, 0.0649, 0.3568, 0.1662, 0.3809]]])
# Qt_bar (t=[64]):
#  tensor([[[0.6472, 0.0000, 0.3528, 0.0000, 0.0000],
#          [0.0000, 0.6472, 0.3528, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.3528, 0.6472, 0.0000],
#          [0.0000, 0.0000, 0.3528, 0.0000, 0.6472]]])
# Posterior p(x_{t-1} | x_t): tensor([[[2.2575e-03, 1.1708e-03, 9.7846e-01, 6.1865e-03, 1.1925e-02],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [4.6683e-04, 9.7323e-04, 9.9036e-01, 2.4907e-03, 5.7086e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 2]])
#
# --- REVERSE STEP p_sample (t=64) ---
# x_t: tensor([[2, 1, 1, 2]])
# Predicted p(x0 | x_t): tensor([[[0.0269, 0.0512, 0.2680, 0.4135, 0.2405],
#          [0.0694, 0.3453, 0.3543, 0.0733, 0.1578],
#          [0.1774, 0.0543, 0.0894, 0.4619, 0.2169],
#          [0.6250, 0.0825, 0.1185, 0.1167, 0.0574]]])
# Qt_bar (t=[63]):
#  tensor([[[0.6560, 0.0000, 0.3440, 0.0000, 0.0000],
#          [0.0000, 0.6560, 0.3440, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.3440, 0.6560, 0.0000],
#          [0.0000, 0.0000, 0.3440, 0.0000, 0.6560]]])
# Posterior p(x_{t-1} | x_t): tensor([[[4.5036e-04, 8.5755e-04, 9.8774e-01, 6.9251e-03, 4.0280e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [1.2826e-02, 1.6927e-03, 9.8191e-01, 2.3946e-03, 1.1775e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 2]])
#
# --- REVERSE STEP p_sample (t=63) ---
# x_t: tensor([[2, 1, 1, 2]])
# Predicted p(x0 | x_t): tensor([[[0.3648, 0.1435, 0.1169, 0.1596, 0.2153],
#          [0.2820, 0.1439, 0.2194, 0.0796, 0.2751],
#          [0.0993, 0.6334, 0.0323, 0.0100, 0.2250],
#          [0.0245, 0.3064, 0.6006, 0.0411, 0.0275]]])
# Qt_bar (t=[62]):
#  tensor([[[0.6648, 0.0000, 0.3352, 0.0000, 0.0000],
#          [0.0000, 0.6648, 0.3352, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.3352, 0.6648, 0.0000],
#          [0.0000, 0.0000, 0.3352, 0.0000, 0.6648]]])
# Posterior p(x_{t-1} | x_t): tensor([[[7.6227e-03, 2.9988e-03, 9.8155e-01, 3.3345e-03, 4.4985e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [2.9210e-04, 3.6498e-03, 9.9524e-01, 4.8959e-04, 3.2708e-04]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 2]])
#
# --- REVERSE STEP p_sample (t=62) ---
# x_t: tensor([[2, 1, 1, 2]])
# Predicted p(x0 | x_t): tensor([[[0.2634, 0.0391, 0.0375, 0.0526, 0.6074],
#          [0.0600, 0.1209, 0.0461, 0.4179, 0.3552],
#          [0.0964, 0.1038, 0.5853, 0.1437, 0.0708],
#          [0.3887, 0.1422, 0.0474, 0.3543, 0.0674]]])
# Qt_bar (t=[61]):
#  tensor([[[0.6735, 0.0000, 0.3265, 0.0000, 0.0000],
#          [0.0000, 0.6735, 0.3265, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.3265, 0.6735, 0.0000],
#          [0.0000, 0.0000, 0.3265, 0.0000, 0.6735]]])
# Posterior p(x_{t-1} | x_t): tensor([[[6.4097e-03, 9.5093e-04, 9.7657e-01, 1.2808e-03, 1.4784e-02],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [9.2899e-03, 3.3977e-03, 9.7723e-01, 8.4688e-03, 1.6118e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 2]])
#
# --- REVERSE STEP p_sample (t=61) ---
# x_t: tensor([[2, 1, 1, 2]])
# Predicted p(x0 | x_t): tensor([[[0.2901, 0.0868, 0.0169, 0.1526, 0.4535],
#          [0.8397, 0.0539, 0.0225, 0.0217, 0.0622],
#          [0.1716, 0.5304, 0.0775, 0.1879, 0.0325],
#          [0.1486, 0.3173, 0.4317, 0.0258, 0.0766]]])
# Qt_bar (t=[60]):
#  tensor([[[0.6823, 0.0000, 0.3177, 0.0000, 0.0000],
#          [0.0000, 0.6823, 0.3177, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.3177, 0.6823, 0.0000],
#          [0.0000, 0.0000, 0.3177, 0.0000, 0.6823]]])
# Posterior p(x_{t-1} | x_t): tensor([[[7.4992e-03, 2.2444e-03, 9.7459e-01, 3.9454e-03, 1.1724e-02],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [2.1035e-03, 4.4896e-03, 9.9196e-01, 3.6456e-04, 1.0841e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 2]])
#
# --- REVERSE STEP p_sample (t=60) ---
# x_t: tensor([[2, 1, 1, 2]])
# Predicted p(x0 | x_t): tensor([[[0.3305, 0.2089, 0.0926, 0.1624, 0.2057],
#          [0.2621, 0.0313, 0.5100, 0.1774, 0.0192],
#          [0.2257, 0.2170, 0.2166, 0.0150, 0.3258],
#          [0.1827, 0.1130, 0.1442, 0.3434, 0.2168]]])
# Qt_bar (t=[59]):
#  tensor([[[0.6910, 0.0000, 0.3090, 0.0000, 0.0000],
#          [0.0000, 0.6910, 0.3090, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.3090, 0.6910, 0.0000],
#          [0.0000, 0.0000, 0.3090, 0.0000, 0.6910]]])
# Posterior p(x_{t-1} | x_t): tensor([[[0.0075, 0.0048, 0.9793, 0.0037, 0.0047],
#          [0.0000, 1.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 1.0000, 0.0000, 0.0000, 0.0000],
#          [0.0038, 0.0024, 0.9821, 0.0072, 0.0045]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 2]])
#
# --- REVERSE STEP p_sample (t=59) ---
# x_t: tensor([[2, 1, 1, 2]])
# Predicted p(x0 | x_t): tensor([[[0.0410, 0.1001, 0.2185, 0.4996, 0.1409],
#          [0.2282, 0.1993, 0.2067, 0.1479, 0.2178],
#          [0.1387, 0.2181, 0.4725, 0.0948, 0.0759],
#          [0.4023, 0.1686, 0.1380, 0.1836, 0.1075]]])
# Qt_bar (t=[58]):
#  tensor([[[0.6996, 0.0000, 0.3004, 0.0000, 0.0000],
#          [0.0000, 0.6996, 0.3004, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.3004, 0.6996, 0.0000],
#          [0.0000, 0.0000, 0.3004, 0.0000, 0.6996]]])
# Posterior p(x_{t-1} | x_t): tensor([[[7.7132e-04, 1.8836e-03, 9.8529e-01, 9.4059e-03, 2.6518e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [8.6147e-03, 3.6106e-03, 9.8154e-01, 3.9327e-03, 2.3013e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 2]])
#
# --- REVERSE STEP p_sample (t=58) ---
# x_t: tensor([[2, 1, 1, 2]])
# Predicted p(x0 | x_t): tensor([[[0.1713, 0.3026, 0.1889, 0.0871, 0.2502],
#          [0.0681, 0.1545, 0.1324, 0.0904, 0.5546],
#          [0.1270, 0.3401, 0.3167, 0.1180, 0.0982],
#          [0.1300, 0.0590, 0.1429, 0.5724, 0.0956]]])
# Qt_bar (t=[57]):
#  tensor([[[0.7082, 0.0000, 0.2918, 0.0000, 0.0000],
#          [0.0000, 0.7082, 0.2918, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.2918, 0.7082, 0.0000],
#          [0.0000, 0.0000, 0.2918, 0.0000, 0.7082]]])
# Posterior p(x_{t-1} | x_t): tensor([[[0.0034, 0.0060, 0.9838, 0.0017, 0.0050],
#          [0.0000, 1.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 1.0000, 0.0000, 0.0000, 0.0000],
#          [0.0028, 0.0013, 0.9816, 0.0123, 0.0021]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 2]])
#
# --- REVERSE STEP p_sample (t=57) ---
# x_t: tensor([[2, 1, 1, 2]])
# Predicted p(x0 | x_t): tensor([[[0.6173, 0.0987, 0.1619, 0.0749, 0.0471],
#          [0.1150, 0.0736, 0.2805, 0.3601, 0.1708],
#          [0.0111, 0.5718, 0.0853, 0.2847, 0.0471],
#          [0.4548, 0.0367, 0.2749, 0.0429, 0.1907]]])
# Qt_bar (t=[56]):
#  tensor([[[0.7168, 0.0000, 0.2832, 0.0000, 0.0000],
#          [0.0000, 0.7168, 0.2832, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.2832, 0.7168, 0.0000],
#          [0.0000, 0.0000, 0.2832, 0.0000, 0.7168]]])
# Posterior p(x_{t-1} | x_t): tensor([[[1.3017e-02, 2.0813e-03, 9.8233e-01, 1.5801e-03, 9.9385e-04],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [8.0122e-03, 6.4589e-04, 9.8723e-01, 7.5644e-04, 3.3603e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 2]])
#
# --- REVERSE STEP p_sample (t=56) ---
# x_t: tensor([[2, 1, 1, 2]])
# Predicted p(x0 | x_t): tensor([[[0.0569, 0.1204, 0.2992, 0.3906, 0.1328],
#          [0.0918, 0.2750, 0.1107, 0.1946, 0.3280],
#          [0.0428, 0.1113, 0.0193, 0.1326, 0.6939],
#          [0.0500, 0.4165, 0.1773, 0.0226, 0.3336]]])
# Qt_bar (t=[55]):
#  tensor([[[0.7253, 0.0000, 0.2747, 0.0000, 0.0000],
#          [0.0000, 0.7253, 0.2747, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.2747, 0.7253, 0.0000],
#          [0.0000, 0.0000, 0.2747, 0.0000, 0.7253]]])
# Posterior p(x_{t-1} | x_t): tensor([[[9.7460e-04, 2.0611e-03, 9.8801e-01, 6.6854e-03, 2.2727e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [1.0385e-03, 8.6482e-03, 9.8292e-01, 4.6932e-04, 6.9255e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 2]])
#
# --- REVERSE STEP p_sample (t=55) ---
# x_t: tensor([[2, 1, 1, 2]])
# Predicted p(x0 | x_t): tensor([[[0.1800, 0.3909, 0.0334, 0.3307, 0.0650],
#          [0.2939, 0.2708, 0.2620, 0.0969, 0.0763],
#          [0.1127, 0.2185, 0.1105, 0.0610, 0.4973],
#          [0.1745, 0.4235, 0.0424, 0.0347, 0.3249]]])
# Qt_bar (t=[54]):
#  tensor([[[0.7338, 0.0000, 0.2662, 0.0000, 0.0000],
#          [0.0000, 0.7338, 0.2662, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.2662, 0.7338, 0.0000],
#          [0.0000, 0.0000, 0.2662, 0.0000, 0.7338]]])
# Posterior p(x_{t-1} | x_t): tensor([[[5.0948e-03, 1.1067e-02, 9.7264e-01, 9.3610e-03, 1.8398e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [4.8353e-03, 1.1734e-02, 9.7347e-01, 9.6086e-04, 9.0029e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 2]])
#
# --- REVERSE STEP p_sample (t=54) ---
# x_t: tensor([[2, 1, 1, 2]])
# Predicted p(x0 | x_t): tensor([[[0.0669, 0.2956, 0.2518, 0.3050, 0.0807],
#          [0.5774, 0.0566, 0.1630, 0.1456, 0.0574],
#          [0.0770, 0.4570, 0.1120, 0.0636, 0.2905],
#          [0.1075, 0.3586, 0.3419, 0.0659, 0.1260]]])
# Qt_bar (t=[53]):
#  tensor([[[0.7422, 0.0000, 0.2578, 0.0000, 0.0000],
#          [0.0000, 0.7422, 0.2578, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.2578, 0.7422, 0.0000],
#          [0.0000, 0.0000, 0.2578, 0.0000, 0.7422]]])
# Posterior p(x_{t-1} | x_t): tensor([[[0.0012, 0.0055, 0.9861, 0.0057, 0.0015],
#          [0.0000, 1.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 1.0000, 0.0000, 0.0000, 0.0000],
#          [0.0017, 0.0058, 0.9893, 0.0011, 0.0020]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 2]])
#
# --- REVERSE STEP p_sample (t=53) ---
# x_t: tensor([[2, 1, 1, 2]])
# Predicted p(x0 | x_t): tensor([[[0.0323, 0.2554, 0.1835, 0.3286, 0.2002],
#          [0.0975, 0.2167, 0.2909, 0.2924, 0.1025],
#          [0.1892, 0.1692, 0.0573, 0.1392, 0.4451],
#          [0.4020, 0.0729, 0.0873, 0.1446, 0.2931]]])
# Qt_bar (t=[52]):
#  tensor([[[0.7505, 0.0000, 0.2495, 0.0000, 0.0000],
#          [0.0000, 0.7505, 0.2495, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.2495, 0.7505, 0.0000],
#          [0.0000, 0.0000, 0.2495, 0.0000, 0.7505]]])
# Posterior p(x_{t-1} | x_t): tensor([[[6.8420e-04, 5.4047e-03, 9.8272e-01, 6.9533e-03, 4.2359e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [1.0390e-02, 1.8851e-03, 9.7641e-01, 3.7363e-03, 7.5759e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 2]])
#
# --- REVERSE STEP p_sample (t=52) ---
# x_t: tensor([[2, 1, 1, 2]])
# Predicted p(x0 | x_t): tensor([[[0.0120, 0.0145, 0.0673, 0.8415, 0.0647],
#          [0.1990, 0.0511, 0.2033, 0.4131, 0.1336],
#          [0.1523, 0.4229, 0.1002, 0.2747, 0.0499],
#          [0.6487, 0.0430, 0.0955, 0.0910, 0.1219]]])
# Qt_bar (t=[51]):
#  tensor([[[0.7588, 0.0000, 0.2412, 0.0000, 0.0000],
#          [0.0000, 0.7588, 0.2412, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.2412, 0.7588, 0.0000],
#          [0.0000, 0.0000, 0.2412, 0.0000, 0.7588]]])
# Posterior p(x_{t-1} | x_t): tensor([[[3.3035e-04, 3.9948e-04, 9.7430e-01, 2.3191e-02, 1.7832e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [1.6705e-02, 1.1064e-03, 9.7671e-01, 2.3430e-03, 3.1381e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 2]])
#
# --- REVERSE STEP p_sample (t=51) ---
# x_t: tensor([[2, 1, 1, 2]])
# Predicted p(x0 | x_t): tensor([[[0.3547, 0.0515, 0.4868, 0.0604, 0.0467],
#          [0.5276, 0.1325, 0.0370, 0.1451, 0.1578],
#          [0.6850, 0.0251, 0.0694, 0.0505, 0.1701],
#          [0.0179, 0.0665, 0.6028, 0.2712, 0.0415]]])
# Qt_bar (t=[50]):
#  tensor([[[0.7670, 0.0000, 0.2330, 0.0000, 0.0000],
#          [0.0000, 0.7670, 0.2330, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.2330, 0.7670, 0.0000],
#          [0.0000, 0.0000, 0.2330, 0.0000, 0.7670]]])
# Posterior p(x_{t-1} | x_t): tensor([[[4.7611e-03, 6.9070e-04, 9.9311e-01, 8.1007e-04, 6.2689e-04],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [2.1050e-04, 7.7995e-04, 9.9534e-01, 3.1814e-03, 4.8706e-04]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 2]])
#
# --- REVERSE STEP p_sample (t=50) ---
# x_t: tensor([[2, 1, 1, 2]])
# Predicted p(x0 | x_t): tensor([[[0.0546, 0.0431, 0.1674, 0.0641, 0.6709],
#          [0.1749, 0.1361, 0.3061, 0.0399, 0.3430],
#          [0.1199, 0.1514, 0.2256, 0.0989, 0.4042],
#          [0.1392, 0.2527, 0.1642, 0.2207, 0.2231]]])
# Qt_bar (t=[49]):
#  tensor([[[0.7751, 0.0000, 0.2249, 0.0000, 0.0000],
#          [0.0000, 0.7751, 0.2249, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.2249, 0.7751, 0.0000],
#          [0.0000, 0.0000, 0.2249, 0.0000, 0.7751]]])
# Posterior p(x_{t-1} | x_t): tensor([[[1.2273e-03, 9.6749e-04, 9.8129e-01, 1.4390e-03, 1.5071e-02],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [3.1491e-03, 5.7161e-03, 9.8110e-01, 4.9919e-03, 5.0453e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 2]])
#
# --- REVERSE STEP p_sample (t=49) ---
# x_t: tensor([[2, 1, 1, 2]])
# Predicted p(x0 | x_t): tensor([[[0.2423, 0.3790, 0.1461, 0.1363, 0.0963],
#          [0.2194, 0.1197, 0.2239, 0.1812, 0.2559],
#          [0.4415, 0.0991, 0.0242, 0.1926, 0.2426],
#          [0.1351, 0.4405, 0.1500, 0.2605, 0.0139]]])
# Qt_bar (t=[48]):
#  tensor([[[0.7832, 0.0000, 0.2168, 0.0000, 0.0000],
#          [0.0000, 0.7832, 0.2168, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.2168, 0.7832, 0.0000],
#          [0.0000, 0.0000, 0.2168, 0.0000, 0.7832]]])
# Posterior p(x_{t-1} | x_t): tensor([[[5.7586e-03, 9.0068e-03, 9.7970e-01, 3.2402e-03, 2.2893e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [3.1822e-03, 1.0379e-02, 9.7997e-01, 6.1371e-03, 3.2821e-04]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 2]])
#
# --- REVERSE STEP p_sample (t=48) ---
# x_t: tensor([[2, 1, 1, 2]])
# Predicted p(x0 | x_t): tensor([[[0.0695, 0.1460, 0.1086, 0.6386, 0.0373],
#          [0.0540, 0.2157, 0.1837, 0.2769, 0.2697],
#          [0.1021, 0.1087, 0.2623, 0.2213, 0.3055],
#          [0.0831, 0.1219, 0.4048, 0.0853, 0.3049]]])
# Qt_bar (t=[47]):
#  tensor([[[0.7911, 0.0000, 0.2089, 0.0000, 0.0000],
#          [0.0000, 0.7911, 0.2089, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.2089, 0.7911, 0.0000],
#          [0.0000, 0.0000, 0.2089, 0.0000, 0.7911]]])
# Posterior p(x_{t-1} | x_t): tensor([[[1.8303e-03, 3.8438e-03, 9.7653e-01, 1.6818e-02, 9.8218e-04],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [1.2374e-03, 1.8159e-03, 9.9114e-01, 1.2696e-03, 4.5401e-03]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 2]])
#
# --- REVERSE STEP p_sample (t=47) ---
# x_t: tensor([[2, 1, 1, 2]])
# Predicted p(x0 | x_t): tensor([[[0.0427, 0.1508, 0.4602, 0.2228, 0.1234],
#          [0.3249, 0.1783, 0.0165, 0.3914, 0.0889],
#          [0.1647, 0.2588, 0.2572, 0.0408, 0.2785],
#          [0.6238, 0.0472, 0.0597, 0.0158, 0.2534]]])
# Qt_bar (t=[46]):
#  tensor([[[0.7990, 0.0000, 0.2010, 0.0000, 0.0000],
# ...
#          [0.1589, 0.0900, 0.2857, 0.3243, 0.1410],
#          [0.3578, 0.5180, 0.0826, 0.0245, 0.0171]]])
# Qt_bar (t=[17]):
#  tensor([[[0.9699, 0.0000, 0.0301, 0.0000, 0.0000],
#          [0.0000, 0.9699, 0.0301, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0301, 0.9699, 0.0000],
#          [0.0000, 0.0000, 0.0301, 0.0000, 0.9699]]])
# Posterior p(x_{t-1} | x_t): tensor([[[6.4101e-04, 1.8691e-04, 9.8782e-01, 7.3069e-03, 4.0421e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 3]])
#
# --- REVERSE STEP p_sample (t=17) ---
# x_t: tensor([[2, 1, 1, 3]])
# Predicted p(x0 | x_t): tensor([[[0.4259, 0.0594, 0.0500, 0.2150, 0.2497],
#          [0.2475, 0.0638, 0.0552, 0.5620, 0.0715],
#          [0.1384, 0.0482, 0.6654, 0.0906, 0.0574],
#          [0.1100, 0.0539, 0.3861, 0.4191, 0.0310]]])
# Qt_bar (t=[16]):
#  tensor([[[0.9733, 0.0000, 0.0267, 0.0000, 0.0000],
#          [0.0000, 0.9733, 0.0267, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0267, 0.9733, 0.0000],
#          [0.0000, 0.0000, 0.0267, 0.0000, 0.9733]]])
# Posterior p(x_{t-1} | x_t): tensor([[[0.0184, 0.0026, 0.9589, 0.0093, 0.0108],
#          [0.0000, 1.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 1.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 1.0000, 0.0000]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 3]])
#
# --- REVERSE STEP p_sample (t=16) ---
# x_t: tensor([[2, 1, 1, 3]])
# Predicted p(x0 | x_t): tensor([[[0.4910, 0.0426, 0.4178, 0.0189, 0.0298],
#          [0.3824, 0.1825, 0.1087, 0.1571, 0.1693],
#          [0.0216, 0.6558, 0.0381, 0.1010, 0.1836],
#          [0.0614, 0.2304, 0.0223, 0.6464, 0.0395]]])
# Qt_bar (t=[15]):
#  tensor([[[0.9765, 0.0000, 0.0235, 0.0000, 0.0000],
#          [0.0000, 0.9765, 0.0235, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0235, 0.9765, 0.0000],
#          [0.0000, 0.0000, 0.0235, 0.0000, 0.9765]]])
# Posterior p(x_{t-1} | x_t): tensor([[[3.6245e-03, 3.1426e-04, 9.9570e-01, 1.3929e-04, 2.2021e-04],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 3]])
#
# --- REVERSE STEP p_sample (t=15) ---
# x_t: tensor([[2, 1, 1, 3]])
# Predicted p(x0 | x_t): tensor([[[0.0680, 0.2466, 0.3003, 0.3130, 0.0721],
#          [0.0808, 0.6233, 0.0399, 0.1291, 0.1267],
#          [0.2785, 0.0282, 0.3873, 0.1529, 0.1531],
#          [0.1011, 0.1201, 0.5072, 0.0258, 0.2458]]])
# Qt_bar (t=[14]):
#  tensor([[[0.9795, 0.0000, 0.0205, 0.0000, 0.0000],
#          [0.0000, 0.9795, 0.0205, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0205, 0.9795, 0.0000],
#          [0.0000, 0.0000, 0.0205, 0.0000, 0.9795]]])
# Posterior p(x_{t-1} | x_t): tensor([[[6.4456e-04, 2.3362e-03, 9.9337e-01, 2.9656e-03, 6.8291e-04],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 3]])
#
# --- REVERSE STEP p_sample (t=14) ---
# x_t: tensor([[2, 1, 1, 3]])
# Predicted p(x0 | x_t): tensor([[[0.1238, 0.1775, 0.0563, 0.4666, 0.1758],
#          [0.0575, 0.1892, 0.4981, 0.0494, 0.2058],
#          [0.1011, 0.1329, 0.1821, 0.3733, 0.2106],
#          [0.1014, 0.0122, 0.6298, 0.2403, 0.0163]]])
# Qt_bar (t=[13]):
#  tensor([[[0.9823, 0.0000, 0.0177, 0.0000, 0.0000],
#          [0.0000, 0.9823, 0.0177, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0177, 0.9823, 0.0000],
#          [0.0000, 0.0000, 0.0177, 0.0000, 0.9823]]])
# Posterior p(x_{t-1} | x_t): tensor([[[0.0046, 0.0066, 0.9650, 0.0173, 0.0065],
#          [0.0000, 1.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 1.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 1.0000, 0.0000]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 3]])
#
# --- REVERSE STEP p_sample (t=13) ---
# x_t: tensor([[2, 1, 1, 3]])
# Predicted p(x0 | x_t): tensor([[[0.0596, 0.1158, 0.1428, 0.2567, 0.4251],
#          [0.0123, 0.0251, 0.6030, 0.3151, 0.0445],
#          [0.0250, 0.0933, 0.1722, 0.0855, 0.6239],
#          [0.0362, 0.4429, 0.0982, 0.3367, 0.0860]]])
# Qt_bar (t=[12]):
#  tensor([[[0.9849, 0.0000, 0.0151, 0.0000, 0.0000],
#          [0.0000, 0.9849, 0.0151, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0151, 0.9849, 0.0000],
#          [0.0000, 0.0000, 0.0151, 0.0000, 0.9849]]])
# Posterior p(x_{t-1} | x_t): tensor([[[9.8217e-04, 1.9074e-03, 9.8588e-01, 4.2278e-03, 7.0011e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 3]])
#
# --- REVERSE STEP p_sample (t=12) ---
# x_t: tensor([[2, 1, 1, 3]])
# Predicted p(x0 | x_t): tensor([[[0.7279, 0.0011, 0.0234, 0.2130, 0.0345],
#          [0.2276, 0.1185, 0.1952, 0.2434, 0.2153],
#          [0.0160, 0.2381, 0.5199, 0.1776, 0.0483],
#          [0.1151, 0.6527, 0.1221, 0.0719, 0.0382]]])
# Qt_bar (t=[11]):
#  tensor([[[0.9873, 0.0000, 0.0127, 0.0000, 0.0000],
#          [0.0000, 0.9873, 0.0127, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0127, 0.9873, 0.0000],
#          [0.0000, 0.0000, 0.0127, 0.0000, 0.9873]]])
# Posterior p(x_{t-1} | x_t): tensor([[[4.5775e-02, 6.7301e-05, 9.3859e-01, 1.3395e-02, 2.1723e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 3]])
#
# --- REVERSE STEP p_sample (t=11) ---
# x_t: tensor([[2, 1, 1, 3]])
# Predicted p(x0 | x_t): tensor([[[0.0299, 0.2241, 0.2017, 0.2952, 0.2490],
#          [0.6207, 0.1525, 0.1335, 0.0780, 0.0153],
#          [0.2801, 0.2075, 0.3108, 0.0299, 0.1717],
#          [0.1568, 0.0615, 0.6095, 0.0230, 0.1492]]])
# Qt_bar (t=[10]):
#  tensor([[[0.9895, 0.0000, 0.0105, 0.0000, 0.0000],
#          [0.0000, 0.9895, 0.0105, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0105, 0.9895, 0.0000],
#          [0.0000, 0.0000, 0.0105, 0.0000, 0.9895]]])
# Posterior p(x_{t-1} | x_t): tensor([[[3.1008e-04, 2.3204e-03, 9.9173e-01, 3.0567e-03, 2.5783e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 3]])
#
# --- REVERSE STEP p_sample (t=10) ---
# x_t: tensor([[2, 1, 1, 3]])
# Predicted p(x0 | x_t): tensor([[[0.2148, 0.0428, 0.3831, 0.2641, 0.0952],
#          [0.1426, 0.0623, 0.0636, 0.1682, 0.5632],
#          [0.2054, 0.1676, 0.1059, 0.4800, 0.0409],
#          [0.0756, 0.1097, 0.2490, 0.5299, 0.0359]]])
# Qt_bar (t=[9]):
#  tensor([[[0.9915, 0.0000, 0.0085, 0.0000, 0.0000],
#          [0.0000, 0.9915, 0.0085, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0085, 0.9915, 0.0000],
#          [0.0000, 0.0000, 0.0085, 0.0000, 0.9915]]])
# Posterior p(x_{t-1} | x_t): tensor([[[1.0967e-03, 2.1850e-04, 9.9685e-01, 1.3482e-03, 4.8575e-04],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 3]])
#
# --- REVERSE STEP p_sample (t=9) ---
# x_t: tensor([[2, 1, 1, 3]])
# Predicted p(x0 | x_t): tensor([[[0.6879, 0.1445, 0.0727, 0.0448, 0.0501],
#          [0.1869, 0.0832, 0.2777, 0.1225, 0.3297],
#          [0.0352, 0.1263, 0.3252, 0.0484, 0.4649],
#          [0.2109, 0.5278, 0.0513, 0.1719, 0.0381]]])
# Qt_bar (t=[8]):
#  tensor([[[0.9933, 0.0000, 0.0067, 0.0000, 0.0000],
#          [0.0000, 0.9933, 0.0067, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0067, 0.9933, 0.0000],
#          [0.0000, 0.0000, 0.0067, 0.0000, 0.9933]]])
# Posterior p(x_{t-1} | x_t): tensor([[[1.5220e-02, 3.1961e-03, 9.7948e-01, 9.9204e-04, 1.1085e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 3]])
#
# --- REVERSE STEP p_sample (t=8) ---
# x_t: tensor([[2, 1, 1, 3]])
# Predicted p(x0 | x_t): tensor([[[0.3014, 0.0497, 0.1494, 0.0630, 0.4364],
#          [0.1526, 0.1056, 0.0308, 0.4607, 0.2503],
#          [0.2960, 0.1507, 0.1111, 0.3815, 0.0607],
#          [0.1673, 0.6030, 0.0339, 0.1773, 0.0186]]])
# Qt_bar (t=[7]):
#  tensor([[[0.9949, 0.0000, 0.0051, 0.0000, 0.0000],
#          [0.0000, 0.9949, 0.0051, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0051, 0.9949, 0.0000],
#          [0.0000, 0.0000, 0.0051, 0.0000, 0.9949]]])
# Posterior p(x_{t-1} | x_t): tensor([[[3.0581e-03, 5.0417e-04, 9.9137e-01, 6.3935e-04, 4.4275e-03],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 3]])
#
# --- REVERSE STEP p_sample (t=7) ---
# x_t: tensor([[2, 1, 1, 3]])
# Predicted p(x0 | x_t): tensor([[[0.1871, 0.2311, 0.4210, 0.0817, 0.0790],
#          [0.6782, 0.0535, 0.0528, 0.1119, 0.1036],
#          [0.7675, 0.0120, 0.0299, 0.1523, 0.0383],
#          [0.4454, 0.1494, 0.1298, 0.0953, 0.1801]]])
# Qt_bar (t=[6]):
#  tensor([[[0.9962, 0.0000, 0.0038, 0.0000, 0.0000],
#          [0.0000, 0.9962, 0.0038, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0038, 0.9962, 0.0000],
#          [0.0000, 0.0000, 0.0038, 0.0000, 0.9962]]])
# Posterior p(x_{t-1} | x_t): tensor([[[6.0232e-04, 7.4418e-04, 9.9814e-01, 2.6320e-04, 2.5448e-04],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 3]])
#
# --- REVERSE STEP p_sample (t=6) ---
# x_t: tensor([[2, 1, 1, 3]])
# Predicted p(x0 | x_t): tensor([[[0.2051, 0.5187, 0.1163, 0.1022, 0.0577],
#          [0.1102, 0.7031, 0.0902, 0.0141, 0.0823],
#          [0.1919, 0.2057, 0.0750, 0.5110, 0.0165],
#          [0.1792, 0.3377, 0.2190, 0.0608, 0.2033]]])
# Qt_bar (t=[5]):
#  tensor([[[0.9974, 0.0000, 0.0026, 0.0000, 0.0000],
#          [0.0000, 0.9974, 0.0026, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0026, 0.9974, 0.0000],
#          [0.0000, 0.0000, 0.0026, 0.0000, 0.9974]]])
# Posterior p(x_{t-1} | x_t): tensor([[[1.9813e-03, 5.0104e-03, 9.9146e-01, 9.8676e-04, 5.5755e-04],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 3]])
#
# --- REVERSE STEP p_sample (t=5) ---
# x_t: tensor([[2, 1, 1, 3]])
# Predicted p(x0 | x_t): tensor([[[0.7524, 0.0965, 0.0988, 0.0182, 0.0341],
#          [0.2920, 0.5136, 0.0585, 0.0988, 0.0371],
#          [0.2693, 0.2544, 0.0497, 0.3267, 0.0999],
#          [0.1787, 0.1849, 0.2109, 0.2434, 0.1820]]])
# Qt_bar (t=[4]):
#  tensor([[[0.9983, 0.0000, 0.0017, 0.0000, 0.0000],
#          [0.0000, 0.9983, 0.0017, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0017, 0.9983, 0.0000],
#          [0.0000, 0.0000, 0.0017, 0.0000, 0.9983]]])
# Posterior p(x_{t-1} | x_t): tensor([[[7.0292e-03, 9.0134e-04, 9.9158e-01, 1.6983e-04, 3.1838e-04],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 3]])
#
# --- REVERSE STEP p_sample (t=4) ---
# x_t: tensor([[2, 1, 1, 3]])
# Predicted p(x0 | x_t): tensor([[[0.3426, 0.0921, 0.3426, 0.1919, 0.0307],
#          [0.0621, 0.0118, 0.5577, 0.0444, 0.3239],
#          [0.1245, 0.1585, 0.4426, 0.2364, 0.0380],
#          [0.2612, 0.2895, 0.1588, 0.2006, 0.0900]]])
# Qt_bar (t=[3]):
#  tensor([[[9.9907e-01, 0.0000e+00, 9.3484e-04, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 9.9907e-01, 9.3484e-04, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 9.3484e-04, 9.9907e-01, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 9.3484e-04, 0.0000e+00, 9.9907e-01]]])
# Posterior p(x_{t-1} | x_t): tensor([[[7.3206e-04, 1.9689e-04, 9.9860e-01, 4.1008e-04, 6.5649e-05],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 3]])
#
# --- REVERSE STEP p_sample (t=3) ---
# x_t: tensor([[2, 1, 1, 3]])
# Predicted p(x0 | x_t): tensor([[[0.5377, 0.0832, 0.1443, 0.2179, 0.0168],
#          [0.2418, 0.1725, 0.1712, 0.1326, 0.2818],
#          [0.1618, 0.0585, 0.2344, 0.1775, 0.3678],
#          [0.0306, 0.1438, 0.1279, 0.4430, 0.2547]]])
# Qt_bar (t=[2]):
#  tensor([[[9.9959e-01, 0.0000e+00, 4.1163e-04, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 9.9959e-01, 4.1163e-04, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 4.1163e-04, 9.9959e-01, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 4.1163e-04, 0.0000e+00, 9.9959e-01]]])
# Posterior p(x_{t-1} | x_t): tensor([[[1.9382e-03, 2.9999e-04, 9.9692e-01, 7.8537e-04, 6.0641e-05],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 3]])
#
# --- REVERSE STEP p_sample (t=2) ---
# x_t: tensor([[2, 1, 1, 3]])
# Predicted p(x0 | x_t): tensor([[[0.2001, 0.3357, 0.0384, 0.2030, 0.2227],
#          [0.1407, 0.1441, 0.5777, 0.0701, 0.0675],
#          [0.2589, 0.0753, 0.1778, 0.2901, 0.1979],
#          [0.0132, 0.4944, 0.1926, 0.2186, 0.0811]]])
# Qt_bar (t=[1]):
#  tensor([[[9.9990e-01, 0.0000e+00, 1.0002e-04, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 9.9990e-01, 1.0002e-04, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 1.0002e-04, 9.9990e-01, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 1.0002e-04, 0.0000e+00, 9.9990e-01]]])
# Posterior p(x_{t-1} | x_t): tensor([[[0.0016, 0.0027, 0.9923, 0.0016, 0.0018],
#          [0.0000, 1.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 1.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 1.0000, 0.0000]]])
# Sampled x_{t-1}: tensor([[2, 1, 1, 3]])
#
# --- REVERSE STEP p_sample (t=1) ---
# x_t: tensor([[2, 1, 1, 3]])
# Predicted p(x0 | x_t): tensor([[[0.2143, 0.1635, 0.0683, 0.4768, 0.0770],
#          [0.1370, 0.4384, 0.0475, 0.2782, 0.0989],
#          [0.1358, 0.6524, 0.0792, 0.0336, 0.0990],
#          [0.3330, 0.2860, 0.2085, 0.1552, 0.0173]]])
# Final x0 sample: tensor([[3, 3, 1, 3]])
#
# === FINAL RESULT ===
# Original x0: tensor([[0, 1, 3, 4]])
# Reconstructed x0_hat: tensor([[3, 3, 1, 3]])
